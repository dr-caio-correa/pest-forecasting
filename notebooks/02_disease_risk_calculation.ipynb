# %% [markdown]
# # Pest Forecasting - Ontario Disease Risk
#
# ---
#
# ## Project context
#
# This notebook transforms the raw hourly weather records collected in Notebook 01 into daily disease risk scores for each monitoring station. The core of the analysis is a Disease Severity Value (DSV) model - a validated agronomic decision rule that translates temperature and leaf wetness conditions into a discrete risk score per day. Cumulative DSV scores are then tracked over the season and compared against published spray thresholds to generate actionable recommendations.
#
# The approach is generalizable: the same pipeline structure applies to any disease or pest whose risk is driven by measurable environmental conditions. Swapping the DSV lookup table and thresholds is sufficient to adapt it to a different pathogen.
#
# ## Inputs
#
# | File | Description |
# |---|---|
# | `data/raw/hourly_weather_data.csv` | Hourly weather records for 99 Ontario stations (from Notebook 01) |
#
# ## Outputs
#
# | File | Description |
# |---|---|
# | `data/processed/daily_disease_risk.csv` | Daily DSV, risk category, cumulative score, and spray flag per station |
# | `outputs/figures/02_monthly_dsv_profile.png` | Mean daily DSV by month across the station network |
# | `outputs/figures/02_cumulative_dsv_trajectories.png` | Season-long cumulative DSV for the highest-risk stations |

# %% [markdown]
# ## 1. Environment setup
#
# All imports, path constants, and visual parameters are defined here. The spray threshold constants match the published decision rules used by Ontario agronomists and must not be changed without updating the corresponding documentation.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
from pathlib import Path

warnings.filterwarnings('ignore', category=pd.errors.DtypeWarning)
warnings.filterwarnings('ignore', category=FutureWarning)

# -- Paths -------------------------------------------------------------------
RAW_PATH  = Path('../data/raw/hourly_weather_data.csv')
PROC_PATH = Path('../data/processed/')
OUTF      = Path('../outputs/figures/')

PROC_PATH.mkdir(parents=True, exist_ok=True)
OUTF.mkdir(parents=True, exist_ok=True)

# -- DSV spray thresholds (cumulative) ---------------------------------------
SPRAY_1 = 135
SPRAY_2 = 180
SPRAY_3 = 225

# -- Wet-hour humidity threshold ---------------------------------------------
WET_HOUR_RH_THRESHOLD = 90

# -- Color palette -----------------------------------------------------------
RISK_COLORS = {
    'LOW':       '#2ca25f',
    'MODERATE':  '#fdae61',
    'HIGH':      '#f46d43',
    'VERY HIGH': '#d7191c',
}

SPRAY_COLORS = {
    'SPRAY 1': '#fdae61',
    'SPRAY 2': '#f46d43',
    'SPRAY 3': '#d7191c',
}

# %% [markdown]
# ## 2. Load hourly weather data
#
# The raw hourly file is loaded and a calendar date field is extracted from the timestamp. This date field is the grouping key for all daily aggregations in Section 3.

# %%
df = pd.read_csv(RAW_PATH, low_memory=False)
df['Date/Time (LST)'] = pd.to_datetime(df['Date/Time (LST)'], errors='coerce')
df['date'] = df['Date/Time (LST)'].dt.date

print(f'Loaded: {len(df):,} hourly records')
print(f'Stations: {df["station_id"].nunique()}')
print(f'Date range: {df["date"].min()} to {df["date"].max()}')
df.head()
# Out:
# Loaded: 2,601,819 hourly records
# Stations: 99
# Date range: 2023-01-01 to 2025-12-31
#       Date/Time (LST)  Longitude (x)  Latitude (y)              Station Name  \
# 0 2025-01-01 00:00:00         -78.27         45.53  ALGONQUIN PARK EAST GATE
# 1 2025-01-01 01:00:00         -78.27         45.53  ALGONQUIN PARK EAST GATE
# 2 2025-01-01 02:00:00         -78.27         45.53  ALGONQUIN PARK EAST GATE
# 3 2025-01-01 03:00:00         -78.27         45.53  ALGONQUIN PARK EAST GATE
# 4 2025-01-01 04:00:00         -78.27         45.53  ALGONQUIN PARK EAST GATE
#
#   Climate ID  Year  Month  Day Time (LST) Flag  ...  Visibility Flag  \
# 0    6080192  2025      1    1      00:00  NaN  ...              NaN
# 1    6080192  2025      1    1      01:00  NaN  ...              NaN
# 2    6080192  2025      1    1      02:00  NaN  ...              NaN
# 3    6080192  2025      1    1      03:00  NaN  ...              NaN
# 4    6080192  2025      1    1      04:00  NaN  ...              NaN
#
# ...

# %% [markdown]
# ## 3. Compute daily weather summaries
#
# Hourly records are collapsed to one row per station per day. Three fields drive the DSV calculation downstream: daily mean temperature, total precipitation, and the count and mean temperature of hours where relative humidity exceeded the wet-hour threshold. Wet-hour count is the primary driver of daily DSV - prolonged leaf wetness is the environmental condition most strongly associated with disease development.

# %%
# Daily aggregates
daily = (
    df.groupby(['Station Name', 'date'])
    .agg(**{
        'Longitude (x)': ('Longitude (x)',       'first'),
        'Latitude (y)':  ('Latitude (y)',         'first'),
        'Climate ID':    ('Climate ID',           'first'),
        'station_id':    ('station_id',           'first'),
        'mean_temp':     ('Temp (°C)',        'mean'),
        'max_rel_hum':   ('Rel Hum (%)',           'max'),
        'precip_mm_sum': ('Precip. Amount (mm)',   'sum'),
    })
    .reset_index()
)

# Wet-hour metrics
wet = (
    df[df['Rel Hum (%)'] >= WET_HOUR_RH_THRESHOLD]
    .groupby(['Station Name', 'date'])
    .agg(
        wet_hours_count=('Rel Hum (%)',    'count'),
        wet_hours_temp= ('Temp (°C)', 'mean'),
    )
    .reset_index()
)

daily = daily.merge(wet, on=['Station Name', 'date'], how='left')
daily['wet_hours_count'] = daily['wet_hours_count'].fillna(0)
daily['wet_hours_temp']  = daily['wet_hours_temp'].fillna(daily['mean_temp'])

# mean_temp and max_rel_hum can be null where the station had no readings that day
# wet_hours_temp inherits those nulls - all three are expected and handled downstream
EXPECTED_NULL_COLS = ['mean_temp', 'max_rel_hum', 'wet_hours_temp']
unexpected_nulls = daily.drop(columns=EXPECTED_NULL_COLS).isna().sum().sum()
assert unexpected_nulls == 0, f"Unexpected nulls in non-weather columns: {daily.drop(columns=EXPECTED_NULL_COLS).isna().sum()[daily.drop(columns=EXPECTED_NULL_COLS).isna().sum() > 0]}"

print(f"Daily records: {len(daily):,}  |  Stations: {daily['station_id'].nunique()}")
print(f"Rows with missing temperature readings: {daily['mean_temp'].isna().sum():,} (stations with no data that day - expected)")
daily.head()
# Out:
# Daily records: 107,408  |  Stations: 98
# Rows with missing temperature readings: 2,041 (stations with no data that day - expected)
#                Station Name        date  Longitude (x)  Latitude (y)  \
# 0  ALGONQUIN PARK EAST GATE  2023-01-01         -78.27         45.53
# 1  ALGONQUIN PARK EAST GATE  2023-01-02         -78.27         45.53
# 2  ALGONQUIN PARK EAST GATE  2023-01-03         -78.27         45.53
# 3  ALGONQUIN PARK EAST GATE  2023-01-04         -78.27         45.53
# 4  ALGONQUIN PARK EAST GATE  2023-01-05         -78.27         45.53
#
#   Climate ID  station_id  mean_temp  max_rel_hum  precip_mm_sum  \
# 0    6080192       42967  -0.345833         98.0            0.2
# 1    6080192       42967   0.470833         98.0            0.4
# 2    6080192       42967   0.183333         97.0            0.7
# 3    6080192       42967  -0.408333         97.0           21.5
# 4    6080192       42967  -1.187500         98.0            8.1
#
# ...

# %% [markdown]
# ## 4. Compute daily Disease Severity Values (DSV)
#
# The DSV model is a published decision rule that converts temperature and wet-hour count into a discrete severity score from 0 to 4. The logic applies different wet-hour thresholds depending on the temperature range, reflecting how pathogen development rate varies with temperature. Days outside the viable temperature range (below 7.2C or above 26.6C) score zero regardless of moisture conditions.

# %%
def calculate_dsv(temp, wet_hours):
    # Returns 0 if temperature is outside viable range or wet_hours is zero.
    # Applies temperature-band lookup rules based on validated agronomic thresholds.
    if wet_hours == 0 or pd.isna(temp):
        return 0
    if 7.2 <= temp <= 11.6:
        thresholds = [0, 15, 18, 21, 24, float('inf')]
    elif 11.7 <= temp <= 15.0:
        thresholds = [0, 12, 15, 18, 21, float('inf')]
    elif 15.1 <= temp <= 26.6:
        thresholds = [0, 9, 12, 15, 18, float('inf')]
    else:
        return 0
    for i, upper in enumerate(thresholds[1:]):
        if wet_hours <= upper:
            return i
    return 0

# %%
daily['dsv'] = daily.apply(
    lambda r: calculate_dsv(r['wet_hours_temp'], r['wet_hours_count']),
    axis=1,
)

print('DSV distribution:')
print(daily['dsv'].value_counts().sort_index().to_string())
# Out:
# DSV distribution:
# dsv
# 0    98253
# 1     4285
# 2     2357
# 3     1442
# 4     1071

# %% [markdown]
# ## 5. Assign risk categories and cumulative spray flags
#
# Daily DSV scores are converted to four categorical risk levels for human-readable output. Cumulative DSV is accumulated over the season per station and compared against three spray thresholds. Reaching a threshold means environmental pressure has built to the point where a preventive intervention is warranted - acting before visible symptoms appear.
#
# The three thresholds represent escalating urgency: a station that reaches SPRAY 3 has already passed SPRAY 1 and SPRAY 2.

# %%
def categorize_risk(dsv):
    if dsv <= 1:
        return 'LOW'
    elif dsv == 2:
        return 'MODERATE'
    elif dsv == 3:
        return 'HIGH'
    else:
        return 'VERY HIGH'


def spray_label(cumulative_dsv):
    if cumulative_dsv >= SPRAY_3:
        return 'SPRAY 3'
    elif cumulative_dsv >= SPRAY_2:
        return 'SPRAY 2'
    elif cumulative_dsv >= SPRAY_1:
        return 'SPRAY 1'
    else:
        return 'NO SPRAY'

# %%
daily['date'] = pd.to_datetime(daily['date'])
daily = daily.sort_values(['Station Name', 'date']).reset_index(drop=True)

daily['disease_risk']         = daily['dsv'].apply(categorize_risk)
daily['dsv_total']            = daily.groupby('Station Name')['dsv'].cumsum()
daily['spray_1']              = daily['dsv_total'] >= SPRAY_1
daily['spray_2']              = daily['dsv_total'] >= SPRAY_2
daily['spray_3']              = daily['dsv_total'] >= SPRAY_3
daily['spray_recommendation'] = daily['dsv_total'].apply(spray_label)

print('Risk category distribution:')
print(daily['disease_risk'].value_counts().to_string())
print()
print('Spray recommendation distribution:')
print(daily['spray_recommendation'].value_counts().to_string())
# Out:
# Risk category distribution:
# disease_risk
# LOW          102538
# MODERATE       2357
# HIGH           1442
# VERY HIGH      1071
#
# Spray recommendation distribution:
# spray_recommendation
# NO SPRAY    83547
# SPRAY 1     13854
# SPRAY 2      6017
# SPRAY 3      3990

# %% [markdown]
# ## 6. Monthly DSV profile across the station network
#
# The seasonal pattern of disease pressure is one of the most useful outputs for planning purposes. This figure shows the mean daily DSV across all stations by month, revealing when risk is negligible (winter months) and when it builds to actionable levels. The profile guides when the alert system should be actively monitored.

# %%
MONTH_NAMES = {
    1:'Jan', 2:'Feb', 3:'Mar', 4:'Apr', 5:'May',  6:'Jun',
    7:'Jul', 8:'Aug', 9:'Sep', 10:'Oct', 11:'Nov', 12:'Dec',
}

monthly_dsv = (
    daily.groupby(daily['date'].dt.month)['dsv']
    .mean()
    .reset_index()
    .rename(columns={'date': 'month', 'dsv': 'mean_dsv'})
)

fig, ax = plt.subplots(figsize=(10, 4))

bars = ax.bar(
    monthly_dsv['month'],
    monthly_dsv['mean_dsv'],
    color='#2c7bb6', alpha=0.85, width=0.7,
)

for bar, val in zip(bars, monthly_dsv['mean_dsv']):
    if val > 0.01:
        ax.annotate(
            f'{val:.2f}',
            xy=(bar.get_x() + bar.get_width() / 2, bar.get_height()),
            xytext=(0, 4), textcoords='offset points',
            ha='center', fontsize=7, color='gray',
        )

ax.set_xticks(monthly_dsv['month'])
ax.set_xticklabels([MONTH_NAMES[m] for m in monthly_dsv['month']])
ax.set_xlabel('Month')
ax.set_ylabel('Mean daily DSV')
ax.set_title('Mean daily Disease Severity Value by month - Ontario station network (2025)')
ax.axhline(0, color='black', lw=0.8, ls=':', alpha=0.5)
ax.spines[['top', 'right']].set_visible(False)

fig.tight_layout()
fig.savefig(OUTF / '02_monthly_dsv_profile.png', dpi=150, bbox_inches='tight')
print('Saved -> outputs/figures/02_monthly_dsv_profile.png')
# Out:
# Saved -> outputs/figures/02_monthly_dsv_profile.png

# %% [markdown]
# ## 7. Cumulative DSV trajectories for highest-risk stations
#
# Cumulative DSV shows how pressure builds over the season and when individual stations cross action thresholds. Stations that accumulate risk fastest experience the most frequent combinations of warmth and moisture - exactly the conditions that require earliest intervention. Horizontal dashed lines mark the three spray thresholds.

# %%
top_stations = (
    daily.groupby('Station Name')['dsv_total']
    .max()
    .nlargest(3)
    .index.tolist()
)

fig, ax = plt.subplots(figsize=(11, 5))

line_colors = ['#d7191c', '#2c7bb6', '#1a9641']

for station, color in zip(top_stations, line_colors):
    sdf = daily[daily['Station Name'] == station].sort_values('date')
    ax.plot(
        sdf['date'], sdf['dsv_total'],
        lw=2.5, color=color, label=station,
    )

for label, threshold, color in [
    ('Spray 1', SPRAY_1, SPRAY_COLORS['SPRAY 1']),
    ('Spray 2', SPRAY_2, SPRAY_COLORS['SPRAY 2']),
    ('Spray 3', SPRAY_3, SPRAY_COLORS['SPRAY 3']),
]:
    ax.axhline(threshold, color=color, lw=1.2, ls='--', alpha=0.8)
    ax.annotate(
        label,
        xy=(daily['date'].max(), threshold),
        xytext=(6, 2), textcoords='offset points',
        fontsize=8, color=color,
    )

ax.axhline(0, color='black', lw=0.8, ls=':', alpha=0.5)
ax.set_xlabel('Date')
ax.set_ylabel('Cumulative DSV')
ax.set_title('Season-long cumulative DSV - three highest-risk stations (2025)')
ax.legend(frameon=False, fontsize=9)
ax.spines[['top', 'right']].set_visible(False)

fig.tight_layout()
fig.savefig(OUTF / '02_cumulative_dsv_trajectories.png', dpi=150, bbox_inches='tight')
print('Saved -> outputs/figures/02_cumulative_dsv_trajectories.png')
# Out:
# Saved -> outputs/figures/02_cumulative_dsv_trajectories.png

# %% [markdown]
# ## 8. Save processed dataset
#
# The daily risk table is saved to `data/processed/`. This file is the input for Notebook 03, which produces the interactive station map and snapshot figures for a user-specified date.

# %%
daily.to_csv(PROC_PATH / 'daily_disease_risk.csv', index=False)
print(f'Saved -> data/processed/daily_disease_risk.csv')
print(f'Shape: {daily.shape}')
# Out:
# Saved -> data/processed/daily_disease_risk.csv
# Shape: (107408, 18)

# %% [markdown]
# ## Summary
#
# | Item | Detail |
# |---|---|
# | Stations processed | 98 stations across Ontario |
# | Daily records | 107,408 station-day rows (2023-2025) |
# | DSV model | Temperature and wet-hour lookup table - validated agronomic decision rule |
# | Wet-hour threshold | Relative humidity >= 90% |
# | Risk categories | LOW (DSV 0-1), MODERATE (2), HIGH (3), VERY HIGH (4) |
# | High or Very High risk days | 2,513 station-days (2.3% of total) |
# | Spray thresholds | Cumulative DSV >= 135 (Spray 1), 180 (Spray 2), 225 (Spray 3) |
# | Station-days with active spray flag | 23,861 (22.2% of total) |
#
# Next: **Notebook 03** loads the processed daily risk table and produces an interactive map showing station-level risk for any user-specified date, plus a static snapshot figure for reporting.
